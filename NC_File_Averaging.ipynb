# %%
import netCDF4 as nc

with nc.Dataset('H:\\CLM_input\\data\\Default.nc', 'r') as src_ds:
    print(src_ds.variables.items())
# Out:
# dict_items([('mxsoil_color', <class 'netCDF4._netCDF4.Variable'>
# int32 mxsoil_color()
#     long_name: maximum numbers of soil colors
#     units: unitless
# unlimited dimensions:
# current shape = ()
# filling on, default _FillValue of -2147483647 used), ('SOIL_COLOR', <class 'netCDF4._netCDF4.Variable'>
# int32 SOIL_COLOR(lsmlat, lsmlon)
#     long_name: soil color
#     units: unitless
# unlimited dimensions:
# current shape = (96, 144)
# filling on, default _FillValue of -2147483647 used), ('PCT_SAND', <class 'netCDF4._netCDF4.Variable'>
# float64 PCT_SAND(nlevsoi, lsmlat, lsmlon)
#     long_name: percent sand
#     units: unitless
# unlimited dimensions:
# current shape = (10, 96, 144)
# filling on, default _FillValue of 9.969209968386869e+36 used), ('PCT_CLAY', <class 'netCDF4._netCDF4.Variable'>
# float64 PCT_CLAY(nlevsoi, lsmlat, lsmlon)
#     long_name: percent clay
#     units: unitless
# unlimited dimensions:
# current shape = (10, 96, 144)
# filling on, default _FillValue of 9.969209968386869e+36 used), ('ORGANIC', <class 'netCDF4._netCDF4.Variable'>
# float64 ORGANIC(nlevsoi, lsmlat, lsmlon)
#     long_name: organic matter density at soil levels
#     units: kg/m3 (assumed carbon content 0.58 gC per gOM)
# unlimited dimensions:
# current shape = (10, 96, 144)
# filling on, default _FillValue of 9.969209968386869e+36 used), ('FMAX', <class 'netCDF4._netCDF4.Variable'>
# float64 FMAX(lsmlat, lsmlon)
#     long_name: maximum fractional saturated area
#     units: unitless
# unlimited dimensions:
# current shape = (96, 144)
# filling on, default _FillValue of 9.969209968386869e+36 used), ('natpft', <class 'netCDF4._netCDF4.Variable'>
# int32 natpft(natpft)
#     long_name: indices of natural PFTs
#     units: index
# unlimited dimensions:
# current shape = (15,)
# filling on, default _FillValue of -2147483647 used), ('cft', <class 'netCDF4._netCDF4.Variable'>
# int32 cft(cft)
#     long_name: indices of CFTs
#     units: index
# unlimited dimensions:
# current shape = (2,)
# filling on, default _FillValue of -2147483647 used), ('LANDFRAC_PFT', <class 'netCDF4._netCDF4.Variable'>
# float64 LANDFRAC_PFT(lsmlat, lsmlon)
#     long_name: land fraction from pft dataset
#     units: unitless
# unlimited dimensions:
# current shape = (96, 144)
# filling on, default _FillValue of 9.969209968386869e+36 used), ('PFTDATA_MASK', <class 'netCDF4._netCDF4.Variable'>
# int32 PFTDATA_MASK(lsmlat, lsmlon)
#     long_name: land mask from pft dataset, indicative of real/fake points
#     units: unitless
# unlimited dimensions:
# current shape = (96, 144)
# filling on, default _FillValue of -2147483647 used), ('PCT_NATVEG', <class 'netCDF4._netCDF4.Variable'>
# float64 PCT_NATVEG(lsmlat, lsmlon)
#     long_name: total percent natural vegetation landunit
#     units: unitless
# unlimited dimensions:
# current shape = (96, 144)
# filling on, default _FillValue of 9.969209968386869e+36 used), ('PCT_CROP', <class 'netCDF4._netCDF4.Variable'>
# float64 PCT_CROP(lsmlat, lsmlon)
#     long_name: total percent crop landunit
#     units: unitless
# unlimited dimensions:
# current shape = (96, 144)
# filling on, default _FillValue of 9.969209968386869e+36 used), ('PCT_NAT_PFT', <class 'netCDF4._netCDF4.Variable'>
# float64 PCT_NAT_PFT(natpft, lsmlat, lsmlon)
#     long_name: percent plant functional type on the natural veg landunit (% of landunit)
#     units: unitless
# unlimited dimensions:
# current shape = (15, 96, 144)
# filling on, default _FillValue of 9.969209968386869e+36 used), ('PCT_CFT', <class 'netCDF4._netCDF4.Variable'>
# float64 PCT_CFT(cft, lsmlat, lsmlon)
#     long_name: percent crop functional type on the crop landunit (% of landunit)
#     units: unitless
# unlimited dimensions:
# current shape = (2, 96, 144)
# filling on, default _FillValue of 9.969209968386869e+36 used), ('MONTHLY_LAI', <class 'netCDF4._netCDF4.Variable'>
# float64 MONTHLY_LAI(time, lsmpft, lsmlat, lsmlon)
#     long_name: monthly leaf area index
#     units: unitless
# unlimited dimensions: time
# current shape = (12, 17, 96, 144)
# filling on, default _FillValue of 9.969209968386869e+36 used), ('MONTHLY_SAI', <class 'netCDF4._netCDF4.Variable'>
# float64 MONTHLY_SAI(time, lsmpft, lsmlat, lsmlon)
#     long_name: monthly stem area index
#     units: unitless
# unlimited dimensions: time
# current shape = (12, 17, 96, 144)
# filling on, default _FillValue of 9.969209968386869e+36 used), ('MONTHLY_HEIGHT_TOP', <class 'netCDF4._netCDF4.Variable'>
# float64 MONTHLY_HEIGHT_TOP(time, lsmpft, lsmlat, lsmlon)
#     long_name: monthly height top
#     units: meters
# unlimited dimensions: time
# current shape = (12, 17, 96, 144)
# filling on, default _FillValue of 9.969209968386869e+36 used), ('MONTHLY_HEIGHT_BOT', <class 'netCDF4._netCDF4.Variable'>
# float64 MONTHLY_HEIGHT_BOT(time, lsmpft, lsmlat, lsmlon)
#     long_name: monthly height bottom
#     units: meters
# unlimited dimensions: time
# current shape = (12, 17, 96, 144)
# filling on, default _FillValue of 9.969209968386869e+36 used), ('time', <class 'netCDF4._netCDF4.Variable'>
# int32 time(time)
#     long_name: Calendar month
#     units: month
# unlimited dimensions: time
# current shape = (12,)
# filling on, default _FillValue of -2147483647 used), ('AREA', <class 'netCDF4._netCDF4.Variable'>
# float64 AREA(lsmlat, lsmlon)
#     long_name: area
#     units: km^2
# unlimited dimensions:
# current shape = (96, 144)
# filling on, default _FillValue of 9.969209968386869e+36 used), ('LONGXY', <class 'netCDF4._netCDF4.Variable'>
# float64 LONGXY(lsmlat, lsmlon)
#     long_name: longitude
#     units: degrees east
# unlimited dimensions:
# current shape = (96, 144)
# filling on, default _FillValue of 9.969209968386869e+36 used), ('LATIXY', <class 'netCDF4._netCDF4.Variable'>
# float64 LATIXY(lsmlat, lsmlon)
#     long_name: latitude
#     units: degrees north
# unlimited dimensions:
# current shape = (96, 144)
# filling on, default _FillValue of 9.969209968386869e+36 used), ('EF1_BTR', <class 'netCDF4._netCDF4.Variable'>
# float64 EF1_BTR(lsmlat, lsmlon)
#     long_name: EF btr (isoprene)
#     units: unitless
# unlimited dimensions:
# current shape = (96, 144)
# filling on, default _FillValue of 9.969209968386869e+36 used), ('EF1_FET', <class 'netCDF4._netCDF4.Variable'>
# float64 EF1_FET(lsmlat, lsmlon)
#     long_name: EF fet (isoprene)
#     units: unitless
# unlimited dimensions:
# current shape = (96, 144)
# filling on, default _FillValue of 9.969209968386869e+36 used), ('EF1_FDT', <class 'netCDF4._netCDF4.Variable'>
# float64 EF1_FDT(lsmlat, lsmlon)
#     long_name: EF fdt (isoprene)
#     units: unitless
# unlimited dimensions:
# current shape = (96, 144)
# filling on, default _FillValue of 9.969209968386869e+36 used), ('EF1_SHR', <class 'netCDF4._netCDF4.Variable'>
# float64 EF1_SHR(lsmlat, lsmlon)
#     long_name: EF shr (isoprene)
#     units: unitless
# unlimited dimensions:
# current shape = (96, 144)
# filling on, default _FillValue of 9.969209968386869e+36 used), ('EF1_GRS', <class 'netCDF4._netCDF4.Variable'>
# float64 EF1_GRS(lsmlat, lsmlon)
#     long_name: EF grs (isoprene)
#     units: unitless
# unlimited dimensions:
# current shape = (96, 144)
# filling on, default _FillValue of 9.969209968386869e+36 used), ('EF1_CRP', <class 'netCDF4._netCDF4.Variable'>
# float64 EF1_CRP(lsmlat, lsmlon)
#     long_name: EF crp (isoprene)
#     units: unitless
# unlimited dimensions:
# current shape = (96, 144)
# filling on, default _FillValue of 9.969209968386869e+36 used), ('CANYON_HWR', <class 'netCDF4._netCDF4.Variable'>
# float64 CANYON_HWR(numurbl, lsmlat, lsmlon)
#     long_name: canyon height to width ratio
#     units: unitless
# unlimited dimensions:
# current shape = (3, 96, 144)
# filling on, default _FillValue of 9.969209968386869e+36 used), ('EM_IMPROAD', <class 'netCDF4._netCDF4.Variable'>
# float64 EM_IMPROAD(numurbl, lsmlat, lsmlon)
#     long_name: emissivity of impervious road
#     units: unitless
# unlimited dimensions:
# current shape = (3, 96, 144)
# filling on, default _FillValue of 9.969209968386869e+36 used), ('EM_PERROAD', <class 'netCDF4._netCDF4.Variable'>
# float64 EM_PERROAD(numurbl, lsmlat, lsmlon)
#     long_name: emissivity of pervious road
#     units: unitless
# unlimited dimensions:
# current shape = (3, 96, 144)
# filling on, default _FillValue of 9.969209968386869e+36 used), ('EM_ROOF', <class 'netCDF4._netCDF4.Variable'>
# float64 EM_ROOF(numurbl, lsmlat, lsmlon)
#     long_name: emissivity of roof
#     units: unitless
# unlimited dimensions:
# current shape = (3, 96, 144)
# filling on, default _FillValue of 9.969209968386869e+36 used), ('EM_WALL', <class 'netCDF4._netCDF4.Variable'>
# float64 EM_WALL(numurbl, lsmlat, lsmlon)
#     long_name: emissivity of wall
#     units: unitless
# unlimited dimensions:
# current shape = (3, 96, 144)
# filling on, default _FillValue of 9.969209968386869e+36 used), ('HT_ROOF', <class 'netCDF4._netCDF4.Variable'>
# float64 HT_ROOF(numurbl, lsmlat, lsmlon)
#     long_name: height of roof
#     units: meters
# unlimited dimensions:
# current shape = (3, 96, 144)
# filling on, default _FillValue of 9.969209968386869e+36 used), ('THICK_ROOF', <class 'netCDF4._netCDF4.Variable'>
# float64 THICK_ROOF(numurbl, lsmlat, lsmlon)
#     long_name: thickness of roof
#     units: meters
# unlimited dimensions:
# current shape = (3, 96, 144)
# filling on, default _FillValue of 9.969209968386869e+36 used), ('THICK_WALL', <class 'netCDF4._netCDF4.Variable'>
# float64 THICK_WALL(numurbl, lsmlat, lsmlon)
#     long_name: thickness of wall
#     units: meters
# unlimited dimensions:
# current shape = (3, 96, 144)
# filling on, default _FillValue of 9.969209968386869e+36 used), ('T_BUILDING_MIN', <class 'netCDF4._netCDF4.Variable'>
# float64 T_BUILDING_MIN(numurbl, lsmlat, lsmlon)
#     long_name: minimum interior building temperature
#     units: K
# unlimited dimensions:
# current shape = (3, 96, 144)
# filling on, default _FillValue of 9.969209968386869e+36 used), ('WIND_HGT_CANYON', <class 'netCDF4._netCDF4.Variable'>
# float64 WIND_HGT_CANYON(numurbl, lsmlat, lsmlon)
#     long_name: height of wind in canyon
#     units: meters
# unlimited dimensions:
# current shape = (3, 96, 144)
# filling on, default _FillValue of 9.969209968386869e+36 used), ('WTLUNIT_ROOF', <class 'netCDF4._netCDF4.Variable'>
# float64 WTLUNIT_ROOF(numurbl, lsmlat, lsmlon)
#     long_name: fraction of roof
#     units: unitless
# unlimited dimensions:
# current shape = (3, 96, 144)
# filling on, default _FillValue of 9.969209968386869e+36 used), ('WTROAD_PERV', <class 'netCDF4._netCDF4.Variable'>
# float64 WTROAD_PERV(numurbl, lsmlat, lsmlon)
#     long_name: fraction of pervious road
#     units: unitless
# unlimited dimensions:
# current shape = (3, 96, 144)
# filling on, default _FillValue of 9.969209968386869e+36 used), ('ALB_IMPROAD_DIR', <class 'netCDF4._netCDF4.Variable'>
# float64 ALB_IMPROAD_DIR(numrad, numurbl, lsmlat, lsmlon)
#     long_name: direct albedo of impervious road
#     units: unitless
# unlimited dimensions:
# current shape = (2, 3, 96, 144)
# filling on, default _FillValue of 9.969209968386869e+36 used), ('ALB_IMPROAD_DIF', <class 'netCDF4._netCDF4.Variable'>
# float64 ALB_IMPROAD_DIF(numrad, numurbl, lsmlat, lsmlon)
#     long_name: diffuse albedo of impervious road
#     units: unitless
# unlimited dimensions:
# current shape = (2, 3, 96, 144)
# filling on, default _FillValue of 9.969209968386869e+36 used), ('ALB_PERROAD_DIR', <class 'netCDF4._netCDF4.Variable'>
# float64 ALB_PERROAD_DIR(numrad, numurbl, lsmlat, lsmlon)
#     long_name: direct albedo of pervious road
#     units: unitless
# unlimited dimensions:
# current shape = (2, 3, 96, 144)
# filling on, default _FillValue of 9.969209968386869e+36 used), ('ALB_PERROAD_DIF', <class 'netCDF4._netCDF4.Variable'>
# float64 ALB_PERROAD_DIF(numrad, numurbl, lsmlat, lsmlon)
#     long_name: diffuse albedo of pervious road
#     units: unitless
# unlimited dimensions:
# current shape = (2, 3, 96, 144)
# filling on, default _FillValue of 9.969209968386869e+36 used), ('ALB_ROOF_DIR', <class 'netCDF4._netCDF4.Variable'>
# float64 ALB_ROOF_DIR(numrad, numurbl, lsmlat, lsmlon)
#     long_name: direct albedo of roof
#     units: unitless
# unlimited dimensions:
# current shape = (2, 3, 96, 144)
# filling on, default _FillValue of 9.969209968386869e+36 used), ('ALB_ROOF_DIF', <class 'netCDF4._netCDF4.Variable'>
# float64 ALB_ROOF_DIF(numrad, numurbl, lsmlat, lsmlon)
#     long_name: diffuse albedo of roof
#     units: unitless
# unlimited dimensions:
# current shape = (2, 3, 96, 144)
# filling on, default _FillValue of 9.969209968386869e+36 used), ('ALB_WALL_DIR', <class 'netCDF4._netCDF4.Variable'>
# float64 ALB_WALL_DIR(numrad, numurbl, lsmlat, lsmlon)
#     long_name: direct albedo of wall
#     units: unitless
# unlimited dimensions:
# current shape = (2, 3, 96, 144)
# filling on, default _FillValue of 9.969209968386869e+36 used), ('ALB_WALL_DIF', <class 'netCDF4._netCDF4.Variable'>
# float64 ALB_WALL_DIF(numrad, numurbl, lsmlat, lsmlon)
#     long_name: diffuse albedo of wall
#     units: unitless
# unlimited dimensions:
# current shape = (2, 3, 96, 144)
# filling on, default _FillValue of 9.969209968386869e+36 used), ('TK_ROOF', <class 'netCDF4._netCDF4.Variable'>
# float64 TK_ROOF(nlevurb, numurbl, lsmlat, lsmlon)
#     long_name: thermal conductivity of roof
#     units: W/m*K
# unlimited dimensions:
# current shape = (5, 3, 96, 144)
# filling on, default _FillValue of 9.969209968386869e+36 used), ('TK_WALL', <class 'netCDF4._netCDF4.Variable'>
# float64 TK_WALL(nlevurb, numurbl, lsmlat, lsmlon)
#     long_name: thermal conductivity of wall
#     units: W/m*K
# unlimited dimensions:
# current shape = (5, 3, 96, 144)
# filling on, default _FillValue of 9.969209968386869e+36 used), ('TK_IMPROAD', <class 'netCDF4._netCDF4.Variable'>
# float64 TK_IMPROAD(nlevurb, numurbl, lsmlat, lsmlon)
#     long_name: thermal conductivity of impervious road
#     units: W/m*K
# unlimited dimensions:
# current shape = (5, 3, 96, 144)
# filling on, default _FillValue of 9.969209968386869e+36 used), ('CV_ROOF', <class 'netCDF4._netCDF4.Variable'>
# float64 CV_ROOF(nlevurb, numurbl, lsmlat, lsmlon)
#     long_name: volumetric heat capacity of roof
#     units: J/m^3*K
# unlimited dimensions:
# current shape = (5, 3, 96, 144)
# filling on, default _FillValue of 9.969209968386869e+36 used), ('CV_WALL', <class 'netCDF4._netCDF4.Variable'>
# float64 CV_WALL(nlevurb, numurbl, lsmlat, lsmlon)
#     long_name: volumetric heat capacity of wall
#     units: J/m^3*K
# unlimited dimensions:
# current shape = (5, 3, 96, 144)
# filling on, default _FillValue of 9.969209968386869e+36 used), ('CV_IMPROAD', <class 'netCDF4._netCDF4.Variable'>
# float64 CV_IMPROAD(nlevurb, numurbl, lsmlat, lsmlon)
#     long_name: volumetric heat capacity of impervious road
#     units: J/m^3*K
# unlimited dimensions:
# current shape = (5, 3, 96, 144)
# filling on, default _FillValue of 9.969209968386869e+36 used), ('NLEV_IMPROAD', <class 'netCDF4._netCDF4.Variable'>
# int32 NLEV_IMPROAD(numurbl, lsmlat, lsmlon)
#     long_name: number of impervious road layers
#     units: unitless
# unlimited dimensions:
# current shape = (3, 96, 144)
# filling on, default _FillValue of -2147483647 used), ('peatf', <class 'netCDF4._netCDF4.Variable'>
# float64 peatf(lsmlat, lsmlon)
#     long_name: peatland fraction
#     units: unitless
# unlimited dimensions:
# current shape = (96, 144)
# filling on, default _FillValue of 9.969209968386869e+36 used), ('zbedrock', <class 'netCDF4._netCDF4.Variable'>
# float64 zbedrock(lsmlat, lsmlon)
#     long_name: soil depth
#     units: m
# unlimited dimensions:
# current shape = (96, 144)
# filling on, default _FillValue of 9.969209968386869e+36 used), ('abm', <class 'netCDF4._netCDF4.Variable'>
# int32 abm(lsmlat, lsmlon)
#     long_name: agricultural fire peak month
#     units: unitless
# unlimited dimensions:
# current shape = (96, 144)
# filling on, default _FillValue of -2147483647 used), ('gdp', <class 'netCDF4._netCDF4.Variable'>
# float64 gdp(lsmlat, lsmlon)
#     long_name: gdp
#     units: unitless
# unlimited dimensions:
# current shape = (96, 144)
# filling on, default _FillValue of 9.969209968386869e+36 used), ('SLOPE', <class 'netCDF4._netCDF4.Variable'>
# float64 SLOPE(lsmlat, lsmlon)
#     long_name: mean topographic slope
#     units: degrees
# unlimited dimensions:
# current shape = (96, 144)
# filling on, default _FillValue of 9.969209968386869e+36 used), ('STD_ELEV', <class 'netCDF4._netCDF4.Variable'>
# float64 STD_ELEV(lsmlat, lsmlon)
#     long_name: standard deviation of elevation
#     units: m
# unlimited dimensions:
# current shape = (96, 144)
# filling on, default _FillValue of 9.969209968386869e+36 used), ('binfl', <class 'netCDF4._netCDF4.Variable'>
# float64 binfl(lsmlat, lsmlon)
#     long_name: VIC b parameter for the Variable Infiltration Capacity Curve
#     units: unitless
# unlimited dimensions:
# current shape = (96, 144)
# filling on, default _FillValue of 9.969209968386869e+36 used), ('Ws', <class 'netCDF4._netCDF4.Variable'>
# float64 Ws(lsmlat, lsmlon)
#     long_name: VIC Ws parameter for the ARNO curve
#     units: unitless
# unlimited dimensions:
# current shape = (96, 144)
# filling on, default _FillValue of 9.969209968386869e+36 used), ('Dsmax', <class 'netCDF4._netCDF4.Variable'>
# float64 Dsmax(lsmlat, lsmlon)
#     long_name: VIC Dsmax parameter for the ARNO curve
#     units: mm/day
# unlimited dimensions:
# current shape = (96, 144)
# filling on, default _FillValue of 9.969209968386869e+36 used), ('Ds', <class 'netCDF4._netCDF4.Variable'>
# float64 Ds(lsmlat, lsmlon)
#     long_name: VIC Ds parameter for the ARNO curve
#     units: unitless
# unlimited dimensions:
# current shape = (96, 144)
# filling on, default _FillValue of 9.969209968386869e+36 used), ('LAKEDEPTH', <class 'netCDF4._netCDF4.Variable'>
# float64 LAKEDEPTH(lsmlat, lsmlon)
#     long_name: lake depth
#     units: m
# unlimited dimensions:
# current shape = (96, 144)
# filling on, default _FillValue of 9.969209968386869e+36 used), ('PCT_WETLAND', <class 'netCDF4._netCDF4.Variable'>
# float64 PCT_WETLAND(lsmlat, lsmlon)
#     long_name: percent wetland
#     units: unitless
# unlimited dimensions:
# current shape = (96, 144)
# filling on, default _FillValue of 9.969209968386869e+36 used), ('PCT_LAKE', <class 'netCDF4._netCDF4.Variable'>
# float64 PCT_LAKE(lsmlat, lsmlon)
#     long_name: percent lake
#     units: unitless
# unlimited dimensions:
# current shape = (96, 144)
# filling on, default _FillValue of 9.969209968386869e+36 used), ('PCT_GLACIER', <class 'netCDF4._netCDF4.Variable'>
# float64 PCT_GLACIER(lsmlat, lsmlon)
#     long_name: percent glacier
#     units: unitless
# unlimited dimensions:
# current shape = (96, 144)
# filling on, default _FillValue of 9.969209968386869e+36 used), ('GLACIER_REGION', <class 'netCDF4._netCDF4.Variable'>
# int32 GLACIER_REGION(lsmlat, lsmlon)
#     long_name: glacier region ID
#     units: unitless
# unlimited dimensions:
# current shape = (96, 144)
# filling on, default _FillValue of -2147483647 used), ('GLC_MEC', <class 'netCDF4._netCDF4.Variable'>
# float64 GLC_MEC(nglcecp1)
#     long_name: Glacier elevation class
#     units: m
# unlimited dimensions:
# current shape = (11,)
# filling on, default _FillValue of 9.969209968386869e+36 used), ('PCT_GLC_MEC', <class 'netCDF4._netCDF4.Variable'>
# float64 PCT_GLC_MEC(nglcec, lsmlat, lsmlon)
#     long_name: percent glacier for each glacier elevation class (% of landunit)
#     units: unitless
# unlimited dimensions:
# current shape = (10, 96, 144)
# filling on, default _FillValue of 9.969209968386869e+36 used), ('TOPO_GLC_MEC', <class 'netCDF4._netCDF4.Variable'>
# float64 TOPO_GLC_MEC(nglcec, lsmlat, lsmlon)
#     long_name: mean elevation on glacier elevation classes
#     units: m
# unlimited dimensions:
# current shape = (10, 96, 144)
# filling on, default _FillValue of 9.969209968386869e+36 used), ('PCT_URBAN', <class 'netCDF4._netCDF4.Variable'>
# float64 PCT_URBAN(numurbl, lsmlat, lsmlon)
#     long_name: percent urban for each density type
#     units: unitless
# unlimited dimensions:
# current shape = (3, 96, 144)
# filling on, default _FillValue of 9.969209968386869e+36 used), ('URBAN_REGION_ID', <class 'netCDF4._netCDF4.Variable'>
# int32 URBAN_REGION_ID(lsmlat, lsmlon)
#     long_name: urban region ID
#     units: unitless
# unlimited dimensions:
# current shape = (96, 144)
# filling on, default _FillValue of -2147483647 used), ('CONST_HARVEST_VH1', <class 'netCDF4._netCDF4.Variable'>
# float64 CONST_HARVEST_VH1(lsmlat, lsmlon)
#     long_name: harvest from primary forest
#     units: gC/m2/yr
# unlimited dimensions:
# current shape = (96, 144)
# filling on, default _FillValue of 9.969209968386869e+36 used), ('CONST_HARVEST_VH2', <class 'netCDF4._netCDF4.Variable'>
# float64 CONST_HARVEST_VH2(lsmlat, lsmlon)
#     long_name: harvest from primary non-forest
#     units: gC/m2/yr
# unlimited dimensions:
# current shape = (96, 144)
# filling on, default _FillValue of 9.969209968386869e+36 used), ('CONST_HARVEST_SH1', <class 'netCDF4._netCDF4.Variable'>
# float64 CONST_HARVEST_SH1(lsmlat, lsmlon)
#     long_name: harvest from secondary mature-forest
#     units: gC/m2/yr
# unlimited dimensions:
# current shape = (96, 144)
# filling on, default _FillValue of 9.969209968386869e+36 used), ('CONST_HARVEST_SH2', <class 'netCDF4._netCDF4.Variable'>
# float64 CONST_HARVEST_SH2(lsmlat, lsmlon)
#     long_name: harvest from secondary young-forest
#     units: gC/m2/yr
# unlimited dimensions:
# current shape = (96, 144)
# filling on, default _FillValue of 9.969209968386869e+36 used), ('CONST_HARVEST_SH3', <class 'netCDF4._netCDF4.Variable'>
# float64 CONST_HARVEST_SH3(lsmlat, lsmlon)
#     long_name: harvest from secondary non-forest
#     units: gC/m2/yr
# unlimited dimensions:
# current shape = (96, 144)
# filling on, default _FillValue of 9.969209968386869e+36 used), ('CONST_GRAZING', <class 'netCDF4._netCDF4.Variable'>
# float64 CONST_GRAZING(lsmlat, lsmlon)
#     long_name: grazing of herbacous pfts
#     units: gC/m2/yr
# unlimited dimensions:
# current shape = (96, 144)
# filling on, default _FillValue of 9.969209968386869e+36 used), ('CONST_FERTNITRO_CFT', <class 'netCDF4._netCDF4.Variable'>
# float64 CONST_FERTNITRO_CFT(cft, lsmlat, lsmlon)
#     long_name: nitrogen fertilizer for each crop
#     units: gN/m2/yr
# unlimited dimensions:
# current shape = (2, 96, 144)
# filling on, default _FillValue of 9.969209968386869e+36 used), ('UNREPRESENTED_PFT_LULCC', <class 'netCDF4._netCDF4.Variable'>
# float64 UNREPRESENTED_PFT_LULCC(natpft, lsmlat, lsmlon)
#     long_name: unrepresented PFT gross LULCC transitions
#     units: unitless
# unlimited dimensions:
# current shape = (15, 96, 144)
# filling on, default _FillValue of 9.969209968386869e+36 used), ('UNREPRESENTED_CFT_LULCC', <class 'netCDF4._netCDF4.Variable'>
# float64 UNREPRESENTED_CFT_LULCC(cft, lsmlat, lsmlon)
#     long_name: unrepresented crop gross LULCC transitions
#     units: unitless
# unlimited dimensions:
# current shape = (2, 96, 144)
# filling on, default _FillValue of 9.969209968386869e+36 used), ('CI', <class 'netCDF4._netCDF4.Variable'>
# float64 CI(time, lsmpft, lsmlat, lsmlon)
#     units: unitless
#     long_name: Clumping index
# unlimited dimensions: time
# current shape = (12, 17, 96, 144)
# filling on, default _FillValue of 9.969209968386869e+36 used)])

# %%
import netCDF4 as nc
import numpy as np
# 打开NetCDF文件进行读写
with nc.Dataset('H:\\CLM_input\\data\\Default.nc', 'r') as ds:

    if 'MONTHLY_HEIGHT_TOP' in ds.variables:
        var1 = ds.variables['MONTHLY_HEIGHT_TOP'][:]

with nc.Dataset('H:\\CLM_input\\data\\Default_0.9.nc', 'r') as ds:

    if 'MONTHLY_HEIGHT_TOP' in ds.variables:
        var2 = ds.variables['MONTHLY_HEIGHT_TOP'][:]
print(var1.shape)
print("Mean of var1_1:", np.mean(var1[1,1,:,:]))
print("Mean of var2_1:", np.mean(var2[1,1,:,:]))

print("Mean of var1_2:", np.mean(var1[1,2,:,:]))
print("Mean of var2_2:", np.mean(var2[1,2,:,:]))

print("Mean of var1_3:", np.mean(var1[1,3,:,:]))
print("Mean of var2_3:", np.mean(var2[1,3,:,:]))

print("Mean of var1_4:", np.mean(var1[1,4,:,:]))
print("Mean of var2_4:", np.mean(var2[1,4,:,:]))
# Out:
# (12, 17, 96, 144)
# Mean of var1_1: 5.175873980566282
# Mean of var2_1: 4.658286582509654
# Mean of var1_2: 5.1676115903066195
# Mean of var2_2: 4.650850431275957
# Mean of var1_3: 4.201861803027158
# Mean of var2_3: 3.781675622724443
# Mean of var1_4: 8.601268859154777
# Mean of var2_4: 7.741141973239299

# %%
import netCDF4 as nc

with nc.Dataset('H:\\CLM_input\\data\\Default.nc', 'r') as src_ds:

    with nc.Dataset('H:\\CLM_input\\data\\Default_1.1.nc', 'w') as dst_ds:

        for name, dimension in src_ds.dimensions.items():
            dst_ds.createDimension(
                name, (len(dimension) if not dimension.isunlimited() else None))
        
        for name, variable in src_ds.variables.items():
            dst_var = dst_ds.createVariable(name, variable.datatype, variable.dimensions)
            dst_var.setncatts({k: variable.getncattr(k) for k in variable.ncattrs()})
            dst_var[:] = variable[:]

        if 'MONTHLY_HEIGHT_TOP' in dst_ds.variables:
            var = dst_ds.variables['MONTHLY_HEIGHT_TOP']
            var[:,1,:,:] *= 1.1
            var[:,2,:,:] *= 1.1
            var[:,3,:,:] *= 1.1
            var[:,4,:,:] *= 1.1
            var[:,5,:,:] *= 1.1
            var[:,6,:,:] *= 1.1
            var[:,7,:,:] *= 1.1
            var[:,8,:,:] *= 1.1

# %%
import netCDF4 as nc

with nc.Dataset('H:\\CLM_input\\data\\Default.nc', 'r') as src_ds:

    with nc.Dataset('H:\\CLM_input\\data\\Default_1.2.nc', 'w') as dst_ds:

        for name, dimension in src_ds.dimensions.items():
            dst_ds.createDimension(
                name, (len(dimension) if not dimension.isunlimited() else None))
        
        for name, variable in src_ds.variables.items():
            dst_var = dst_ds.createVariable(name, variable.datatype, variable.dimensions)
            dst_var.setncatts({k: variable.getncattr(k) for k in variable.ncattrs()})
            dst_var[:] = variable[:]

        if 'MONTHLY_HEIGHT_TOP' in dst_ds.variables:
            var = dst_ds.variables['MONTHLY_HEIGHT_TOP']
            var[:,1,:,:] *= 1.2
            var[:,2,:,:] *= 1.2
            var[:,3,:,:] *= 1.2
            var[:,4,:,:] *= 1.2
            var[:,5,:,:] *= 1.2
            var[:,6,:,:] *= 1.2
            var[:,7,:,:] *= 1.2
            var[:,8,:,:] *= 1.2

# %%
import netCDF4 as nc

with nc.Dataset('H:\\CLM_input\\data\\Default.nc', 'r') as src_ds:

    with nc.Dataset('H:\\CLM_input\\data\\Default_0.9.nc', 'w') as dst_ds:

        for name, dimension in src_ds.dimensions.items():
            dst_ds.createDimension(
                name, (len(dimension) if not dimension.isunlimited() else None))
        
        for name, variable in src_ds.variables.items():
            dst_var = dst_ds.createVariable(name, variable.datatype, variable.dimensions)
            dst_var.setncatts({k: variable.getncattr(k) for k in variable.ncattrs()})
            dst_var[:] = variable[:]

        if 'MONTHLY_HEIGHT_TOP' in dst_ds.variables:
            var = dst_ds.variables['MONTHLY_HEIGHT_TOP']
            var[:,1,:,:] *= 0.9
            var[:,2,:,:] *= 0.9
            var[:,3,:,:] *= 0.9
            var[:,4,:,:] *= 0.9
            var[:,5,:,:] *= 0.9
            var[:,6,:,:] *= 0.9
            var[:,7,:,:] *= 0.9
            var[:,8,:,:] *= 0.9

# %%
import netCDF4 as nc

with nc.Dataset('H:\\CLM_input\\data\\Default.nc', 'r') as src_ds:

    with nc.Dataset('H:\\CLM_input\\data\\Default_0.8.nc', 'w') as dst_ds:

        for name, dimension in src_ds.dimensions.items():
            dst_ds.createDimension(
                name, (len(dimension) if not dimension.isunlimited() else None))
        
        for name, variable in src_ds.variables.items():
            dst_var = dst_ds.createVariable(name, variable.datatype, variable.dimensions)
            dst_var.setncatts({k: variable.getncattr(k) for k in variable.ncattrs()})
            dst_var[:] = variable[:]

        if 'MONTHLY_HEIGHT_TOP' in dst_ds.variables:
            var = dst_ds.variables['MONTHLY_HEIGHT_TOP']
            var[:,1,:,:] *= 0.8
            var[:,2,:,:] *= 0.8
            var[:,3,:,:] *= 0.8
            var[:,4,:,:] *= 0.8
            var[:,5,:,:] *= 0.8
            var[:,6,:,:] *= 0.8
            var[:,7,:,:] *= 0.8
            var[:,8,:,:] *= 0.8

# %%
import netCDF4 as nc

# 打开NetCDF文件进行读取
with nc.Dataset('H:\\CLM_input\\data\\Default.nc', 'r') as ds:
    data = ds.variables["MONTHLY_HEIGHT_TOP"][:]
    print(data.shape)
    print(data[1,2,:,:])
    
    
    # 打印所有的变量名称
    # print("Variables in the NetCDF file:")
    # for var_name in ds.variables:
        # print(var_name)

        # 如果你还想打印每个变量的数据:
        # 注意：这可能会产生大量的输出，取决于文件的大小和数据量
        # 如果只是想查看文件结构，最好不要这样做
# Out:
# (12, 17, 96, 144)

# %%
import netCDF4 as nc
import numpy as np

# 设置数据的路径和文件名模板
base_path = 'G:\\Hangkai\\CTH_ET project\\simulated data\\Default_0.8_case\\archive\\Default_0.8_case\\lnd\\hist\\'
file_template = 'Default_0.8_case.clm2.h0.{}-02-01-00000.nc'

# 用于存储平均数据的字典
avg_data = {}

# 循环读取2010年到2014年的数据
for year in range(2010, 2015):
    file_path = base_path + file_template.format(year)
    with nc.Dataset(file_path, 'r') as ds:
        # 只在第一次迭代时获取变量列表
        if year == 2010:
            variables = list(ds.variables.keys())

        # 对每个变量进行处理
        for var_name in variables:
            if var_name not in avg_data:
                avg_data[var_name] = ds.variables[var_name][:]
            else:
                avg_data[var_name] += ds.variables[var_name][:]

# 计算平均值
for var_name in avg_data:
    avg_data[var_name] /= 5

# 创建新的NetCDF文件来存储平均数据
with nc.Dataset('G:\\Hangkai\\CTH_ET project\\simulated data\\Default_0.8_average_data_2001_2014.nc', 'w') as new_ds:
    # 使用最后一次读取的原始数据文件作为模板复制维度和属性
    with nc.Dataset(file_path, 'r') as ds:
        # 复制维度
        for name, dim in ds.dimensions.items():
            new_ds.createDimension(name, len(dim) if not dim.isunlimited() else None)

        # 复制并存储变量
        for var_name, data in avg_data.items():
            # 根据原文件创建变量
            original_var = ds.variables[var_name]
            new_var = new_ds.createVariable(var_name, original_var.datatype, original_var.dimensions)
            new_var.setncatts({attr: original_var.getncattr(attr) for attr in original_var.ncattrs()})
            new_var[:] = data

print("Average data saved!")
# Out:
# ---------------------------------------------------------------------------
# UFuncTypeError                            Traceback (most recent call last)
# Cell In[34], line 24
#      22                 avg_data[var_name] = ds.variables[var_name][:]
#      23             else:
# ---> 24                 avg_data[var_name] += ds.variables[var_name][:]
#      26 # 计算平均值
#      27 for var_name in avg_data:
#
# File ~\AppData\Local\miniconda3\lib\site-packages\numpy\ma\core.py:4296, in MaskedArray.__iadd__(self, other)
#    4294     if m is not nomask:
#    4295         self._mask += m
# -> 4296 self._data.__iadd__(np.where(self._mask, self.dtype.type(0),
#    4297                              getdata(other)))
#    4298 return self
#
# UFuncTypeError: ufunc 'add' did not contain a loop with signature matching types (dtype('S1'), dtype('S1')) -> None

# %%
import netCDF4 as nc
import numpy as np

# 从2010年开始到2014年 四年的平均！
# 2001年到2009年的九年都是初始化

# 设置数据的路径和文件名模板
base_path = 'G:\\Hangkai\\CTH_ET project\\simulated data\\Default_0.8_case\\archive\\Default_0.8_case\\lnd\\hist\\'
file_template = 'Default_0.8_case.clm2.h0.{}-02-01-00000.nc'

# 初始化存储所有变量数据的字典
data_dict = {}
data_types = {}

# 读取第一个年份的文件来初始化data_dict
first_ds = nc.Dataset(base_path + file_template.format(2010), 'r')

with nc.Dataset(base_path + file_template.format(2010), 'r') as ds:
    for var_name in ds.variables:
        if var_name not in ['time', 'time_bounds', 'date_written', 'time_written']:  # 排除某些不需要计算平均值的变量
            data_dict[var_name] = ds.variables[var_name][:]
            data_types[var_name] = ds.variables[var_name].dtype

# 循环读取2001年到2014年的数据
for year in range(2011, 2015):  # 从2011开始，因为2001年的数据已经在上面读取了
    file_path = base_path + file_template.format(year)
    with nc.Dataset(file_path, 'r') as ds:
        for var_name in data_dict:
            data_dict[var_name] += ds.variables[var_name][:]

# 计算每个变量的平均值
for var_name in data_dict:
    # 先将数组转换为浮点类型
    data_dict[var_name] = data_dict[var_name].astype(np.float64)
    data_dict[var_name] /= 5
    data_dict[var_name] = data_dict[var_name].astype(data_types[var_name])

# 创建新的NetCDF文件来存储平均数据
with nc.Dataset('G:\\Hangkai\\CTH_ET project\\simulated data\\Default_0.8_average_data_2001_2014.nc', 'w') as new_ds:
    # 使用first_ds文件的维度来创建新文件的维度
    for name, dim in first_ds.dimensions.items():
        new_ds.createDimension(name, len(dim) if not dim.isunlimited() else None)
    
    # 写入每个变量的平均数据
    for var_name, avg_value in data_dict.items():
        # 提取_FillValue属性（如果存在的话）
        fill_value = None
        if '_FillValue' in first_ds.variables[var_name].ncattrs():
            fill_value = getattr(first_ds.variables[var_name], '_FillValue')
        
        new_var = new_ds.createVariable(var_name, data_types[var_name], first_ds.variables[var_name].dimensions, fill_value=fill_value)
        new_var[:] = avg_value
        
        # 复制原变量的属性到新变量
        for attr_name in first_ds.variables[var_name].ncattrs():
            if attr_name != '_FillValue':  # 已经在变量创建时处理了
                setattr(new_var, attr_name, getattr(first_ds.variables[var_name], attr_name))

first_ds.close()
print("Average data saved!")
# Out:
# Average data saved!

# %%
import netCDF4 as nc
import numpy as np

# 从2010年开始到2014年 四年的平均！
# 2001年到2009年的九年都是初始化

# 设置数据的路径和文件名模板
base_path = 'G:\\Hangkai\\CTH_ET project\\simulated data\\Default_0.9_case\\archive\\Default_0.9_case\\lnd\\hist\\'
file_template = 'Default_0.9_case.clm2.h0.{}-02-01-00000.nc'

# 初始化存储所有变量数据的字典
data_dict = {}
data_types = {}

# 读取第一个年份的文件来初始化data_dict
first_ds = nc.Dataset(base_path + file_template.format(2010), 'r')

with nc.Dataset(base_path + file_template.format(2010), 'r') as ds:
    for var_name in ds.variables:
        if var_name not in ['time', 'time_bounds', 'date_written', 'time_written']:  # 排除某些不需要计算平均值的变量
            data_dict[var_name] = ds.variables[var_name][:]
            data_types[var_name] = ds.variables[var_name].dtype

# 循环读取2001年到2014年的数据
for year in range(2011, 2015):  # 从2011开始，因为2001年的数据已经在上面读取了
    file_path = base_path + file_template.format(year)
    with nc.Dataset(file_path, 'r') as ds:
        for var_name in data_dict:
            data_dict[var_name] += ds.variables[var_name][:]

# 计算每个变量的平均值
for var_name in data_dict:
    # 先将数组转换为浮点类型
    data_dict[var_name] = data_dict[var_name].astype(np.float64)
    data_dict[var_name] /= 5
    data_dict[var_name] = data_dict[var_name].astype(data_types[var_name])

# 创建新的NetCDF文件来存储平均数据
with nc.Dataset('G:\\Hangkai\\CTH_ET project\\simulated data\\Default_0.9_average_data_2001_2014.nc', 'w') as new_ds:
    # 使用first_ds文件的维度来创建新文件的维度
    for name, dim in first_ds.dimensions.items():
        new_ds.createDimension(name, len(dim) if not dim.isunlimited() else None)
    
    # 写入每个变量的平均数据
    for var_name, avg_value in data_dict.items():
        # 提取_FillValue属性（如果存在的话）
        fill_value = None
        if '_FillValue' in first_ds.variables[var_name].ncattrs():
            fill_value = getattr(first_ds.variables[var_name], '_FillValue')
        
        new_var = new_ds.createVariable(var_name, data_types[var_name], first_ds.variables[var_name].dimensions, fill_value=fill_value)
        new_var[:] = avg_value
        
        # 复制原变量的属性到新变量
        for attr_name in first_ds.variables[var_name].ncattrs():
            if attr_name != '_FillValue':  # 已经在变量创建时处理了
                setattr(new_var, attr_name, getattr(first_ds.variables[var_name], attr_name))

first_ds.close()
print("Average data saved!")
# Out:
# Average data saved!

# %%
import netCDF4 as nc
import numpy as np

# 从2010年开始到2014年 五年的平均！
# 2001年到2009年的九年都是初始化

# 设置数据的路径和文件名模板
base_path = 'G:\\Hangkai\\CTH_ET project\\simulated data\\Default_1.1_case\\archive\\Default_1.1_case\\lnd\\hist\\'
file_template = 'Default_1.1_case.clm2.h0.{}-02-01-00000.nc'

# 初始化存储所有变量数据的字典
data_dict = {}
data_types = {}

# 读取第一个年份的文件来初始化data_dict
first_ds = nc.Dataset(base_path + file_template.format(2010), 'r')

with nc.Dataset(base_path + file_template.format(2010), 'r') as ds:
    for var_name in ds.variables:
        if var_name not in ['time', 'time_bounds', 'date_written', 'time_written']:  # 排除某些不需要计算平均值的变量
            data_dict[var_name] = ds.variables[var_name][:]
            data_types[var_name] = ds.variables[var_name].dtype

# 循环读取2001年到2014年的数据
for year in range(2011, 2015):  # 从2011开始，因为2001年的数据已经在上面读取了
    file_path = base_path + file_template.format(year)
    with nc.Dataset(file_path, 'r') as ds:
        for var_name in data_dict:
            data_dict[var_name] += ds.variables[var_name][:]

# 计算每个变量的平均值
for var_name in data_dict:
    # 先将数组转换为浮点类型
    data_dict[var_name] = data_dict[var_name].astype(np.float64)
    data_dict[var_name] /= 5
    data_dict[var_name] = data_dict[var_name].astype(data_types[var_name])

# 创建新的NetCDF文件来存储平均数据
with nc.Dataset('G:\\Hangkai\\CTH_ET project\\simulated data\\Default_1.1_average_data_2001_2014.nc', 'w') as new_ds:
    # 使用first_ds文件的维度来创建新文件的维度
    for name, dim in first_ds.dimensions.items():
        new_ds.createDimension(name, len(dim) if not dim.isunlimited() else None)
    
    # 写入每个变量的平均数据
    for var_name, avg_value in data_dict.items():
        # 提取_FillValue属性（如果存在的话）
        fill_value = None
        if '_FillValue' in first_ds.variables[var_name].ncattrs():
            fill_value = getattr(first_ds.variables[var_name], '_FillValue')
        
        new_var = new_ds.createVariable(var_name, data_types[var_name], first_ds.variables[var_name].dimensions, fill_value=fill_value)
        new_var[:] = avg_value
        
        # 复制原变量的属性到新变量
        for attr_name in first_ds.variables[var_name].ncattrs():
            if attr_name != '_FillValue':  # 已经在变量创建时处理了
                setattr(new_var, attr_name, getattr(first_ds.variables[var_name], attr_name))

first_ds.close()
print("Average data saved!")
# Out:
# Average data saved!

# %%
import netCDF4 as nc
import numpy as np

# 从2010年开始到2014年 四年的平均！
# 2001年到2009年的九年都是初始化

# 设置数据的路径和文件名模板
base_path = 'G:\\Hangkai\\CTH_ET project\\simulated data\\Default_1.2_case\\archive\\Default_1.2_case\\lnd\\hist\\'
file_template = 'Default_1.2_case.clm2.h0.{}-02-01-00000.nc'

# 初始化存储所有变量数据的字典
data_dict = {}
data_types = {}

# 读取第一个年份的文件来初始化data_dict
first_ds = nc.Dataset(base_path + file_template.format(2010), 'r')

with nc.Dataset(base_path + file_template.format(2010), 'r') as ds:
    for var_name in ds.variables:
        if var_name not in ['time', 'time_bounds', 'date_written', 'time_written']:  # 排除某些不需要计算平均值的变量
            data_dict[var_name] = ds.variables[var_name][:]
            data_types[var_name] = ds.variables[var_name].dtype

# 循环读取2001年到2014年的数据
for year in range(2011, 2015):  # 从2011开始，因为2001年的数据已经在上面读取了
    file_path = base_path + file_template.format(year)
    with nc.Dataset(file_path, 'r') as ds:
        for var_name in data_dict:
            data_dict[var_name] += ds.variables[var_name][:]

# 计算每个变量的平均值
for var_name in data_dict:
    # 先将数组转换为浮点类型
    data_dict[var_name] = data_dict[var_name].astype(np.float64)
    data_dict[var_name] /= 5
    data_dict[var_name] = data_dict[var_name].astype(data_types[var_name])

# 创建新的NetCDF文件来存储平均数据
with nc.Dataset('G:\\Hangkai\\CTH_ET project\\simulated data\\Default_1.2_average_data_2001_2014.nc', 'w') as new_ds:
    # 使用first_ds文件的维度来创建新文件的维度
    for name, dim in first_ds.dimensions.items():
        new_ds.createDimension(name, len(dim) if not dim.isunlimited() else None)
    
    # 写入每个变量的平均数据
    for var_name, avg_value in data_dict.items():
        # 提取_FillValue属性（如果存在的话）
        fill_value = None
        if '_FillValue' in first_ds.variables[var_name].ncattrs():
            fill_value = getattr(first_ds.variables[var_name], '_FillValue')
        
        new_var = new_ds.createVariable(var_name, data_types[var_name], first_ds.variables[var_name].dimensions, fill_value=fill_value)
        new_var[:] = avg_value
        
        # 复制原变量的属性到新变量
        for attr_name in first_ds.variables[var_name].ncattrs():
            if attr_name != '_FillValue':  # 已经在变量创建时处理了
                setattr(new_var, attr_name, getattr(first_ds.variables[var_name], attr_name))

first_ds.close()
print("Average data saved!")
# Out:
# Average data saved!

# %%
import netCDF4 as nc
import numpy as np

# 从2010年开始到2014年 四年的平均！
# 2001年到2009年的九年都是初始化

# 设置数据的路径和文件名模板
base_path = 'G:\\Hangkai\\CTH_ET project\\product data\\Default_case\\archive\\Default_case\\lnd\\hist\\'
file_template = 'Default_case.clm2.h0.{}-02-01-00000.nc'

# 初始化存储所有变量数据的字典
data_dict = {}
data_types = {}

# 读取第一个年份的文件来初始化data_dict
first_ds = nc.Dataset(base_path + file_template.format(2010), 'r')

with nc.Dataset(base_path + file_template.format(2010), 'r') as ds:
    for var_name in ds.variables:
        if var_name not in ['time', 'time_bounds', 'date_written', 'time_written']:  # 排除某些不需要计算平均值的变量
            data_dict[var_name] = ds.variables[var_name][:]
            data_types[var_name] = ds.variables[var_name].dtype

# 循环读取2001年到2014年的数据
for year in range(2011, 2015):  # 从2011开始，因为2001年的数据已经在上面读取了
    file_path = base_path + file_template.format(year)
    with nc.Dataset(file_path, 'r') as ds:
        for var_name in data_dict:
            data_dict[var_name] += ds.variables[var_name][:]

# 计算每个变量的平均值
for var_name in data_dict:
    # 先将数组转换为浮点类型
    data_dict[var_name] = data_dict[var_name].astype(np.float64)
    data_dict[var_name] /= 5
    data_dict[var_name] = data_dict[var_name].astype(data_types[var_name])

# 创建新的NetCDF文件来存储平均数据
with nc.Dataset('G:\\Hangkai\\CTH_ET project\\product data\\Default_average_data_2010_2014.nc', 'w') as new_ds:
    # 使用first_ds文件的维度来创建新文件的维度
    for name, dim in first_ds.dimensions.items():
        new_ds.createDimension(name, len(dim) if not dim.isunlimited() else None)
    
    # 写入每个变量的平均数据
    for var_name, avg_value in data_dict.items():
        # 提取_FillValue属性（如果存在的话）
        fill_value = None
        if '_FillValue' in first_ds.variables[var_name].ncattrs():
            fill_value = getattr(first_ds.variables[var_name], '_FillValue')
        
        new_var = new_ds.createVariable(var_name, data_types[var_name], first_ds.variables[var_name].dimensions, fill_value=fill_value)
        new_var[:] = avg_value
        
        # 复制原变量的属性到新变量
        for attr_name in first_ds.variables[var_name].ncattrs():
            if attr_name != '_FillValue':  # 已经在变量创建时处理了
                setattr(new_var, attr_name, getattr(first_ds.variables[var_name], attr_name))

first_ds.close()
print("Average data saved!")
# Out:
# Average data saved!

# %%
import netCDF4 as nc
import numpy as np

# 从2010年开始到2014年 四年的平均！
# 2001年到2009年的九年都是初始化

# 设置数据的路径和文件名模板
base_path = 'G:\\Hangkai\\CTH_ET project\\product data\\Max_case\\archive\\Max_case\\lnd\\hist\\'
file_template = 'Max_case.clm2.h0.{}-02-01-00000.nc'

# 初始化存储所有变量数据的字典
data_dict = {}
data_types = {}

# 读取第一个年份的文件来初始化data_dict
first_ds = nc.Dataset(base_path + file_template.format(2010), 'r')

with nc.Dataset(base_path + file_template.format(2010), 'r') as ds:
    for var_name in ds.variables:
        if var_name not in ['time', 'time_bounds', 'date_written', 'time_written']:  # 排除某些不需要计算平均值的变量
            data_dict[var_name] = ds.variables[var_name][:]
            data_types[var_name] = ds.variables[var_name].dtype

# 循环读取2001年到2014年的数据
for year in range(2011, 2015):  # 从2011开始，因为2001年的数据已经在上面读取了
    file_path = base_path + file_template.format(year)
    with nc.Dataset(file_path, 'r') as ds:
        for var_name in data_dict:
            data_dict[var_name] += ds.variables[var_name][:]

# 计算每个变量的平均值
for var_name in data_dict:
    # 先将数组转换为浮点类型
    data_dict[var_name] = data_dict[var_name].astype(np.float64)
    data_dict[var_name] /= 5
    data_dict[var_name] = data_dict[var_name].astype(data_types[var_name])

# 创建新的NetCDF文件来存储平均数据
with nc.Dataset('G:\\Hangkai\\CTH_ET project\\product data\\Max_average_data_2010_2014.nc', 'w') as new_ds:
    # 使用first_ds文件的维度来创建新文件的维度
    for name, dim in first_ds.dimensions.items():
        new_ds.createDimension(name, len(dim) if not dim.isunlimited() else None)
    
    # 写入每个变量的平均数据
    for var_name, avg_value in data_dict.items():
        # 提取_FillValue属性（如果存在的话）
        fill_value = None
        if '_FillValue' in first_ds.variables[var_name].ncattrs():
            fill_value = getattr(first_ds.variables[var_name], '_FillValue')
        
        new_var = new_ds.createVariable(var_name, data_types[var_name], first_ds.variables[var_name].dimensions, fill_value=fill_value)
        new_var[:] = avg_value
        
        # 复制原变量的属性到新变量
        for attr_name in first_ds.variables[var_name].ncattrs():
            if attr_name != '_FillValue':  # 已经在变量创建时处理了
                setattr(new_var, attr_name, getattr(first_ds.variables[var_name], attr_name))

first_ds.close()
print("Average data saved!")
# Out:
# Average data saved!

# %%
import netCDF4 as nc
import numpy as np

# 从2010年开始到2014年 四年的平均！
# 2001年到2009年的九年都是初始化

# 设置数据的路径和文件名模板
base_path = 'G:\\Hangkai\\CTH_ET project\\product data\\Median_case\\archive\\Median_case\\lnd\\hist\\'
file_template = 'Median_case.clm2.h0.{}-02-01-00000.nc'

# 初始化存储所有变量数据的字典
data_dict = {}
data_types = {}

# 读取第一个年份的文件来初始化data_dict
first_ds = nc.Dataset(base_path + file_template.format(2010), 'r')

with nc.Dataset(base_path + file_template.format(2010), 'r') as ds:
    for var_name in ds.variables:
        if var_name not in ['time', 'time_bounds', 'date_written', 'time_written']:  # 排除某些不需要计算平均值的变量
            data_dict[var_name] = ds.variables[var_name][:]
            data_types[var_name] = ds.variables[var_name].dtype

# 循环读取2001年到2014年的数据
for year in range(2011, 2015):  # 从2011开始，因为2001年的数据已经在上面读取了
    file_path = base_path + file_template.format(year)
    with nc.Dataset(file_path, 'r') as ds:
        for var_name in data_dict:
            data_dict[var_name] += ds.variables[var_name][:]

# 计算每个变量的平均值
for var_name in data_dict:
    # 先将数组转换为浮点类型
    data_dict[var_name] = data_dict[var_name].astype(np.float64)
    data_dict[var_name] /= 5
    data_dict[var_name] = data_dict[var_name].astype(data_types[var_name])

# 创建新的NetCDF文件来存储平均数据
with nc.Dataset('G:\\Hangkai\\CTH_ET project\\product data\\Median_average_data_2010_2014.nc', 'w') as new_ds:
    # 使用first_ds文件的维度来创建新文件的维度
    for name, dim in first_ds.dimensions.items():
        new_ds.createDimension(name, len(dim) if not dim.isunlimited() else None)
    
    # 写入每个变量的平均数据
    for var_name, avg_value in data_dict.items():
        # 提取_FillValue属性（如果存在的话）
        fill_value = None
        if '_FillValue' in first_ds.variables[var_name].ncattrs():
            fill_value = getattr(first_ds.variables[var_name], '_FillValue')
        
        new_var = new_ds.createVariable(var_name, data_types[var_name], first_ds.variables[var_name].dimensions, fill_value=fill_value)
        new_var[:] = avg_value
        
        # 复制原变量的属性到新变量
        for attr_name in first_ds.variables[var_name].ncattrs():
            if attr_name != '_FillValue':  # 已经在变量创建时处理了
                setattr(new_var, attr_name, getattr(first_ds.variables[var_name], attr_name))

first_ds.close()
print("Average data saved!")
# Out:
# Average data saved!

# %%
import netCDF4 as nc
import numpy as np

# 从2010年开始到2014年 四年的平均！
# 2001年到2009年的九年都是初始化

# 设置数据的路径和文件名模板
base_path = 'G:\\Hangkai\\CTH_ET project\\product data\\Mean_case\\archive\\Mean_case\\lnd\\hist\\'
file_template = 'Mean_case.clm2.h0.{}-02-01-00000.nc'

# 初始化存储所有变量数据的字典
data_dict = {}
data_types = {}

# 读取第一个年份的文件来初始化data_dict
first_ds = nc.Dataset(base_path + file_template.format(2010), 'r')

with nc.Dataset(base_path + file_template.format(2010), 'r') as ds:
    for var_name in ds.variables:
        if var_name not in ['time', 'time_bounds', 'date_written', 'time_written']:  # 排除某些不需要计算平均值的变量
            data_dict[var_name] = ds.variables[var_name][:]
            data_types[var_name] = ds.variables[var_name].dtype

# 循环读取2001年到2014年的数据
for year in range(2011, 2015):  # 从2011开始，因为2001年的数据已经在上面读取了
    file_path = base_path + file_template.format(year)
    with nc.Dataset(file_path, 'r') as ds:
        for var_name in data_dict:
            data_dict[var_name] += ds.variables[var_name][:]

# 计算每个变量的平均值
for var_name in data_dict:
    # 先将数组转换为浮点类型
    data_dict[var_name] = data_dict[var_name].astype(np.float64)
    data_dict[var_name] /= 5
    data_dict[var_name] = data_dict[var_name].astype(data_types[var_name])

# 创建新的NetCDF文件来存储平均数据
with nc.Dataset('G:\\Hangkai\\CTH_ET project\\product data\\Mean_average_data_2010_2014.nc', 'w') as new_ds:
    # 使用first_ds文件的维度来创建新文件的维度
    for name, dim in first_ds.dimensions.items():
        new_ds.createDimension(name, len(dim) if not dim.isunlimited() else None)
    
    # 写入每个变量的平均数据
    for var_name, avg_value in data_dict.items():
        # 提取_FillValue属性（如果存在的话）
        fill_value = None
        if '_FillValue' in first_ds.variables[var_name].ncattrs():
            fill_value = getattr(first_ds.variables[var_name], '_FillValue')
        
        new_var = new_ds.createVariable(var_name, data_types[var_name], first_ds.variables[var_name].dimensions, fill_value=fill_value)
        new_var[:] = avg_value
        
        # 复制原变量的属性到新变量
        for attr_name in first_ds.variables[var_name].ncattrs():
            if attr_name != '_FillValue':  # 已经在变量创建时处理了
                setattr(new_var, attr_name, getattr(first_ds.variables[var_name], attr_name))

first_ds.close()
print("Average data saved!")
# Out:
# Average data saved!

# %%
import netCDF4 as nc

# 打开NetCDF文件进行读取
with nc.Dataset('G:\\Hangkai\\CTH_ET project\\Final_data\\GEDI Mean.nc', 'r') as ds:
    # 打印所有的变量名称
    print("Variables in the NetCDF file:")
    for var_name in ds.variables:
        print(var_name)

        # 如果你还想打印每个变量的数据:
        # 注意：这可能会产生大量的输出，取决于文件的大小和数据量
        # 如果只是想查看文件结构，最好不要这样做
        data = ds.variables["FCEV"][:].shape
        print(data)
# Out:
# Variables in the NetCDF file:
# levgrnd
# (12, 50430)
# levlak
# (12, 50430)
# levdcmp
# (12, 50430)
# mcdate
# (12, 50430)
# mcsec
# (12, 50430)
# mdcur
# (12, 50430)
# mscur
# (12, 50430)
# nstep
# (12, 50430)
# lon
# (12, 50430)
# lat
# (12, 50430)
# area
# (12, 50430)
# landfrac
# (12, 50430)
# landmask
# (12, 50430)
# pftmask
# (12, 50430)
# nbedrock
# (12, 50430)
# grid1d_lon
# (12, 50430)
# grid1d_lat
# (12, 50430)
# grid1d_ixy
# (12, 50430)
# grid1d_jxy
# (12, 50430)
# land1d_lon
# (12, 50430)
# land1d_lat
# (12, 50430)
# land1d_ixy
# (12, 50430)
# land1d_jxy
# (12, 50430)
# land1d_wtgcell
# (12, 50430)
# land1d_ityplunit
# (12, 50430)
# land1d_active
# (12, 50430)
# cols1d_lon
# (12, 50430)
# cols1d_lat
# (12, 50430)
# cols1d_ixy
# (12, 50430)
# cols1d_jxy
# (12, 50430)
# cols1d_wtgcell
# (12, 50430)
# cols1d_wtlunit
# (12, 50430)
# cols1d_itype_col
# (12, 50430)
# cols1d_itype_lunit
# (12, 50430)
# cols1d_active
# (12, 50430)
# pfts1d_lon
# (12, 50430)
# pfts1d_lat
# (12, 50430)
# pfts1d_ixy
# (12, 50430)
# pfts1d_jxy
# (12, 50430)
# pfts1d_wtgcell
# (12, 50430)
# pfts1d_wtlunit
# (12, 50430)
# pfts1d_wtcol
# (12, 50430)
# pfts1d_itype_veg
# (12, 50430)
# pfts1d_itype_col
# (12, 50430)
# pfts1d_itype_lunit
# (12, 50430)
# pfts1d_active
# (12, 50430)
# EFLX_LH_TOT
# (12, 50430)
# EFLX_SOIL_GRND
# (12, 50430)
# FCEV
# (12, 50430)
# FCTR
# (12, 50430)
# FGEV
# (12, 50430)
# FPSN
# (12, 50430)
# FPSN_WC
# (12, 50430)
# FPSN_WJ
# (12, 50430)
# FPSN_WP
# (12, 50430)
# FSH
# (12, 50430)
# FSH_G
# (12, 50430)
# FSH_V
# (12, 50430)
# Q2M
# (12, 50430)
# QFLX_EVAP_TOT
# (12, 50430)
# QFLX_RAIN_GRND
# (12, 50430)
# QFLX_SNOW_GRND
# (12, 50430)
# QH2OSFC
# (12, 50430)
# QVEGE
# (12, 50430)
# QVEGT
# (12, 50430)
# Qh
# (12, 50430)
# Qle
# (12, 50430)
# Rnet
# (12, 50430)
# TG
# (12, 50430)
# TSA
# (12, 50430)
# TV
# (12, 50430)
# Z0HV
# (12, 50430)
# Z0M
# (12, 50430)
# Z0MV
# (12, 50430)
# Z0QV
# (12, 50430)
